# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
IBS_time = pd.read_table('IBS_data_proton.dat', sep="\s+")
structure = pd.read_table('IBS_structure.dat', sep="\s+")
beam = pd.read_table('IBS_beam.dat', sep="\s+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Professional\AppData\Local\Temp\ipykernel_19300\3490971865.py:1: SyntaxWarning: invalid escape sequence '\s'
#   IBS_time = pd.read_table('IBS_data_proton.dat', sep="\s+")
# C:\Users\Professional\AppData\Local\Temp\ipykernel_19300\3490971865.py:2: SyntaxWarning: invalid escape sequence '\s'
#   structure = pd.read_table('IBS_structure.dat', sep="\s+")
# C:\Users\Professional\AppData\Local\Temp\ipykernel_19300\3490971865.py:3: SyntaxWarning: invalid escape sequence '\s'
#   beam = pd.read_table('IBS_beam.dat', sep="\s+")

# %%
# do same but attach it to the dataframe
IBS_time['t_all'] = IBS_time.apply(lambda row: 1/((1/np.abs(row.t_h)) + (1/np.abs(row.t_v))), axis=1)
IBS_time['t_l_abs'] = IBS_time.apply(lambda row: np.abs(row.t_l), axis=1)
IBS_time['t_h_abs'] = IBS_time.apply(lambda row: np.abs(row.t_h), axis=1)
IBS_time['t_v_abs'] = IBS_time.apply(lambda row: np.abs(row.t_v), axis=1)
IBS_time['t'] = IBS_time[['t_l_abs','t_h_abs', 't_v_abs']].min(axis=1)
print(IBS_time)
# Out:
#                structure  kinetic_energy         t_l         t_h          t_v  \
# 0                Regular             2.0   -759.3774    204.1717     206.8691
# 1                Regular             3.0 -11806.1200    993.6039    1381.9670
# 2                Regular             4.0   5221.1350   2702.2430    8426.6870
# 3                Regular             5.0   4276.7340   4905.2680  156714.0000
# 4                Regular             6.0   4621.7250   7217.5990  -71867.2900
# 5                Regular             7.0   5369.7290   9645.3760  -67446.4200
# 6                Regular             8.0   6380.9730  12302.2900  -83089.4100
# 7                Regular             9.0   7620.9390  15283.1100 -109683.1000
# 8                Regular            10.0   9083.1530  18655.6700 -147523.8000
# 9                Regular            11.0  10771.2100  22471.2400 -198615.3000
# 10               Regular            12.6  13962.4500  29601.3600 -315215.0000
# 11              Resonant             7.0   6152.8050    845.5162 -208572.4000
# 12              Resonant             8.0   7449.1680   1178.5900 -169611.9000
# 13              Resonant             9.0   9008.7020   1584.0420 -192078.8000
# 14              Resonant            10.0  10833.5200   2068.5240 -238080.5000
# 15              Resonant            11.0  12932.7500   2638.6690 -304479.9000
# 16              Resonant            12.6  16893.5100   3745.5680 -458645.8000
# 17  Regular_and_Resonant             7.0   5898.9200   1531.3790  -91152.7200
# 18  Regular_and_Resonant             8.0   7061.7640   2116.2470 -105076.3000
# 19  Regular_and_Resonant             9.0   8475.1710   2821.3970 -134556.1000
# 20  Regular_and_Resonant            10.0  10136.0300   3657.5550 -177853.8000
# 21  Regular_and_Resonant            11.0  12050.3400   4635.4370 -236771.4000
# 22  Regular_and_Resonant            12.6  15666.0400   6521.4680 -371504.5000
#
#         sigE         t_all     t_l_abs     t_h_abs      t_v_abs           t
# 0   1.671202    102.755775    759.3774    204.1717     206.8691    204.1717
# 1   1.590594    578.020130  11806.1200    993.6039    1381.9670    993.6039
# 2   1.556338   2046.104698   5221.1350   2702.2430    8426.6870   2702.2430
# 3   1.538497   4756.389376   4276.7340   4905.2680  156714.0000   4276.7340
# 4   1.527998   6558.892438   4621.7250   7217.5990   71867.2900   4621.7250
# 5   1.521289   8438.590285   5369.7290   9645.3760   67446.4200   5369.7290
# 6   1.516739  10715.712350   6380.9730  12302.2900   83089.4100   6380.9730
# 7   1.513509  13414.017137   7620.9390  15283.1100  109683.1000   7620.9390
# 8   1.511133  16561.343769   9083.1530  18655.6700  147523.8000   9083.1530
# 9   1.509334  20187.262752  10771.2100  22471.2400  198615.3000  10771.2100
# 10  1.507247  27060.179779  13962.4500  29601.3600  315215.0000  13962.4500
# 11  1.521289    842.102463   6152.8050    845.5162  208572.4000    845.5162
# 12  1.516739   1170.456793   7449.1680   1178.5900  169611.9000   1178.5900
# 13  1.513509   1571.085518   9008.7020   1584.0420  192078.8000   1584.0420
# 14  1.511133   2050.706765  10833.5200   2068.5240  238080.5000   2068.5240
# 15  1.509334   2615.998361  12932.7500   2638.6690  304479.9000   2638.6690
# 16  1.507247   3715.227296  16893.5100   3745.5680  458645.8000   3745.5680
# 17  1.521289   1506.076692   5898.9200   1531.3790   91152.7200   1531.3790
# 18  1.516739   2074.467030   7061.7640   2116.2470  105076.3000   2116.2470
# 19  1.513509   2763.452422   8475.1710   2821.3970  134556.1000   2821.3970
# 20  1.511133   3583.853228  10136.0300   3657.5550  177853.8000   3657.5550
# 21  1.509334   4546.428435  12050.3400   4635.4370  236771.4000   4635.4370
# 22  1.507247   6408.963705  15666.0400   6521.4680  371504.5000   6521.4680

# %%
#print(IBS_time)
#temp_X = parameters_X.merge(particles_X, on=['I'])
#data_X = temp_X.merge(tss_X, on=['I'])
#IBS_time[IBS_time['structure'] == 'Regular'].plot('kinetic_energy', y = ['t_l', 't_h', 't_v'])
#IBS_time[IBS_time['structure'] == 'Resonant'].plot('kinetic_energy', y = ['t_l', 't_h', 't_v'])
#IBS_time[IBS_time['structure'] == 'Regular_and_Resonant'].plot('kinetic_energy', y = ['t_l', 't_h', 't_v'])

regular = IBS_time[IBS_time['structure'] == 'Regular']
resonant = IBS_time[IBS_time['structure'] == 'Resonant']
regular_and_resonant = IBS_time[IBS_time['structure'] == 'Regular_and_Resonant']
print(regular)
# Out:
#    structure  kinetic_energy         t_l         t_h          t_v      sigE  \
# 0    Regular             2.0   -759.3774    204.1717     206.8691  1.671202
# 1    Regular             3.0 -11806.1200    993.6039    1381.9670  1.590594
# 2    Regular             4.0   5221.1350   2702.2430    8426.6870  1.556338
# 3    Regular             5.0   4276.7340   4905.2680  156714.0000  1.538497
# 4    Regular             6.0   4621.7250   7217.5990  -71867.2900  1.527998
# 5    Regular             7.0   5369.7290   9645.3760  -67446.4200  1.521289
# 6    Regular             8.0   6380.9730  12302.2900  -83089.4100  1.516739
# 7    Regular             9.0   7620.9390  15283.1100 -109683.1000  1.513509
# 8    Regular            10.0   9083.1530  18655.6700 -147523.8000  1.511133
# 9    Regular            11.0  10771.2100  22471.2400 -198615.3000  1.509334
# 10   Regular            12.6  13962.4500  29601.3600 -315215.0000  1.507247
#
#            t_all     t_l_abs     t_h_abs      t_v_abs           t
# 0     102.755775    759.3774    204.1717     206.8691    204.1717
# 1     578.020130  11806.1200    993.6039    1381.9670    993.6039
# 2    2046.104698   5221.1350   2702.2430    8426.6870   2702.2430
# 3    4756.389376   4276.7340   4905.2680  156714.0000   4276.7340
# 4    6558.892438   4621.7250   7217.5990   71867.2900   4621.7250
# 5    8438.590285   5369.7290   9645.3760   67446.4200   5369.7290
# 6   10715.712350   6380.9730  12302.2900   83089.4100   6380.9730
# 7   13414.017137   7620.9390  15283.1100  109683.1000   7620.9390
# 8   16561.343769   9083.1530  18655.6700  147523.8000   9083.1530
# 9   20187.262752  10771.2100  22471.2400  198615.3000  10771.2100
# 10  27060.179779  13962.4500  29601.3600  315215.0000  13962.4500

# %%
plt.plot(regular['kinetic_energy'], regular['t_all'], 'k')
plt.plot(resonant['kinetic_energy'], resonant['t_all'], 'b')
plt.plot(regular_and_resonant['kinetic_energy'], regular_and_resonant['t_all'], 'r')
plt.legend(['Regular', 'Resonant', 'Regular and resonant'])
plt.title("Intrabeam Scattering")
plt.xlabel('Energy, GeV/u')
plt.ylabel('IBS time, sec')
plt.grid()
plt.xlim(1, 12.6)
plt.ylim(0, 30000)
plt.show()

# %%
plt.plot(regular['kinetic_energy'], regular['t'], 'k')
plt.plot(resonant['kinetic_energy'], resonant['t'], 'b')
plt.plot(regular_and_resonant['kinetic_energy'], regular_and_resonant['t'], 'r')
plt.legend(['Regular', 'Resonant', 'Regular and resonant'])
plt.title("Intrabeam Scattering")
plt.xlabel('Energy, GeV/u')
plt.ylabel('IBS time, sec')
plt.grid()
plt.xlim(1, 12.6)
plt.ylim(0, 20000)
plt.show()

# %%
plt.plot(regular['kinetic_energy'], regular['t_h'], 'k')
plt.plot(resonant['kinetic_energy'], resonant['t_h'], 'b')
plt.plot(regular_and_resonant['kinetic_energy'], regular_and_resonant['t_h'], 'r')
plt.legend(['Regular', 'Resonant', 'Regular and resonant'])
plt.title("IBS time in horisontal plane")
plt.show()

# %%
plt.plot(regular['kinetic_energy'], regular['t_v'], 'k')
plt.plot(resonant['kinetic_energy'], resonant['t_v'], 'b')
plt.plot(regular_and_resonant['kinetic_energy'], regular_and_resonant['t_v'], 'r')
plt.legend(['Regular', 'Resonant', 'Regular and resonant'])
plt.title("IBS time in vertical plane")
plt.show()

# %%
plt.plot(regular['kinetic_energy'], regular['t_l'], 'k')
plt.plot(resonant['kinetic_energy'], resonant['t_l'], 'b')
plt.plot(regular_and_resonant['kinetic_energy'], regular_and_resonant['t_l'], 'r')
plt.legend(['Regular', 'Resonant', 'Regular and resonant'])
plt.title("IBS time in longitudinal plane")
plt.show()

# %% [markdown]
# Stochastic Cooling

# %%
#parameters
c = 3*1e8 # m/s, speed of light
m_p = 0.938 # GeV
f_max = 4*1e9 # Hz
f_min = 2*1e9 # Hz
W = f_max - f_min # Hz, bandwidth of the system
N_bunch = 1.2*1e12 # number of particles per one bunch
C_orb = 503.04 # m Accelerator length
F_bunch = 4 # bunch distribution parameter: 2pi - gauss, 4 - 
sigma_bunch = 0.6 # m, longitudinal sigma length
dp_p = 1.5*1e-3

# %%
N = N_bunch * (C_orb / (F_bunch * sigma_bunch)) # number of particles on orbit
N/1e14
# Out:
# 2.5152

# %%
nu = W / N
nu_Lebedev = (2*W*sigma_bunch) / (N*C_orb)
tau_limit = 1 / nu # limitation
print( (1/nu)/1e5, (1/nu_Lebedev)/1e5)
# Out:
# 1.2576000000000003 527.1859200000001

# %%
alpha_1 = 0.0279239
alpha_2 = 0.0154573
L_1 = 179.696
alpha_3 = 0.00587438
alpha_4 = 0.00320331
L_2 = 323.344

# %%
import numpy as np
def beta (gamma):
    return np.sqrt(1 - 1 / gamma**2)
def gamma (kinetic_energy, # GeV
           mass #mass
          ):
    return (kinetic_energy / mass) + 1
def eta (alpha, gamma):
    return alpha - (1 / (gamma**2))
# Time of fligth
def T (gamma, L):
    return L / (beta(gamma)*c)
#Mixing factor pickup-kicker
def M_pk (f_max, 
          f_min,
          gamma,
          alpha_pk, # alpha pickup - kicker
          L_pk, # Length
          dp_p):
    return 1 / (2 * (f_max+f_min)*eta(alpha_pk, gamma)*T(gamma, L_pk)*dp_p)
#Mixing factor pickup-kicker
def M_kp (f_max, 
          f_min,
          gamma,
          alpha_kp, # alpha kicker - pickup
          L_kp, # Length
          dp_p):
    return 1 / (2 * (f_max-f_min)*eta(alpha_kp, gamma)*T(gamma, L_kp)*dp_p)

# %%
def rate (f_max, 
          f_min,
          gamma,
          alpha_pk, # alpha pickup - kicker
          L_pk, # Length
          alpha_kp, # alpha kicker - pickup
          L_kp, # Length
          dp_p):
    return (W / N) * (1-1/(M_pk(f_max, f_min, gamma, alpha_pk, L_pk, dp_p))**2)**2/(M_kp(f_max, f_min, gamma, alpha_kp, L_kp, dp_p))
def tau (f_max, 
         f_min,
         gamma,
         alpha_pk, # alpha pickup - kicker
         L_pk, # Length
         alpha_kp, # alpha kicker - pickup
         L_kp, # Length
         dp_p):
    return 1 / rate(f_max, f_min, gamma, alpha_pk, L_pk, alpha_kp, L_kp, dp_p)

# %%
energy = np.linspace(0.0001, 15, 100)
tau_limitation = np.full(shape=energy.shape, fill_value = tau_limit)

# %%
plt.plot(energy, np.abs(tau(f_max, f_min, gamma(energy, m_p), alpha_1, L_1, alpha_2, L_2, dp_p)))
plt.plot(energy, np.abs(tau(f_max, f_min, gamma(energy, m_p), alpha_3, L_1, alpha_4, L_2, dp_p)))
plt.plot(energy, np.abs(tau(f_max, f_min, gamma(energy, m_p), alpha_1, L_1, -alpha_2, L_2, dp_p)))
plt.plot(energy, tau_limitation)
plt.ylim(0, 8e6)
plt.xlim(0, 15)
plt.grid()
plt.legend(['Regular', 'Resonant', 'Combined', 'Optimal'])
plt.title("Analitical Stochastic Cooling")
plt.show()

# %%
plt.plot(energy, np.abs(tau(f_max, f_min, gamma(energy, m_p), alpha_1, L_1, alpha_2, L_2, dp_p)))
plt.plot(energy, np.abs(tau(f_max, f_min, gamma(energy, m_p), alpha_3, L_1, alpha_4, L_2, dp_p)))
plt.plot(energy, np.abs(tau(f_max, f_min, gamma(energy, m_p), alpha_1, L_1, -alpha_2, L_2, dp_p)))
plt.plot(energy, tau_limitation)
plt.plot(regular['kinetic_energy'], regular['t'], 'k')
plt.plot(resonant['kinetic_energy'], resonant['t'], 'b')
plt.plot(regular_and_resonant['kinetic_energy'], regular_and_resonant['t'], 'r')
plt.ylim(0, 8e4)
plt.xlim(0, 15)
plt.grid()
plt.legend(['Regular', 'Resonant', 'Combined', 'Optimal'])
plt.title("Comparison")
plt.show()
